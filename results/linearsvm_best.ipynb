# %%
# Best SVM after grid search: {'svm__l1_ratio': 0.2, 'tfidf__ngram_range': (1, 5)}

import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDClassifier
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report
import eli5

# pipeline
pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(lowercase=False, analyzer='char', max_df=0.7, ngram_range=(1,5))),
    ('svm', SGDClassifier(loss='hinge', penalty='elasticnet', fit_intercept=True, class_weight='balanced', average=False, alpha=1e-5, l1_ratio=0.2))
    ])

# data
df = pd.read_csv('processed_data_nospace.csv')
X, y = df.phonetic_transcription.fillna(' '), df.language_classification
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)

#fitting
model = pipeline.fit(X_train, y_train)

# predicting & evaluating
y_pred = model.predict(X_test)
cr = classification_report(y_test, y_pred)
print(cr)
# Out:
# C:\Users\tine-\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
#               precision    recall  f1-score   support
#
#           NL       0.88      0.86      0.87     10762
#           VL       0.73      0.77      0.75      5240
#
#    micro avg       0.83      0.83      0.83     16002
#    macro avg       0.81      0.81      0.81     16002
# weighted avg       0.83      0.83      0.83     16002
# Explanation(estimator="SGDClassifier(alpha=1e-05, average=False, class_weight='balanced',\n       early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,\n       l1_ratio=0.2, learning_rate='optimal', loss='hinge', max_iter=None,\n       n_iter=None, n_iter_no_change=5, n_jobs=None, penalty='elasticnet',\n       power_t=0.5, random_state=None, shuffle=True, tol=None,\n       validation_fraction=0.1, verbose=0, warm_start=False)", description="\nFeatures with largest coefficients.\nCaveats:\n1. Be careful with features which are not\n   independent - weights don't show their importance.\n2. If scale of input features is different then scale of coefficients\n   will also be different, making direct comparison between coefficient values\n   incorrect.\n3. Depending on regularization, rare features sometimes may have high\n   coefficients; this doesn't mean they contribute much to the\n   classification result for most examples.\n", error=None, method='linear model', is_regression=False, targets=[TargetExplanation(target='VL', feature_weights=FeatureWeights(pos=[FeatureWeight(feature='h@t', weight=5.912547944855458, std=None, value=None), FeatureWeight(feature='G', weight=5.663310678898848, std=None, value=None), FeatureWeight(feature='dA', weight=5.3560807552589464, std=None, value=None), FeatureWeight(feature='@n', weight=5.27880707973565, std=None, value=None), FeatureWeight(feature='v@r', weight=5.164270188857715, std=None, value=None), FeatureWeight(feature='gd', weight=4.997834930976147, std=None, value=None), FeatureWeight(feature='pf', weight=4.711887786979021, std=None, value=None), FeatureWeight(feature='tx', weight=4.5251617831062045, std=None, value=None), FeatureWeight(feature='@r', weight=4.475657079495736, std=None, value=None), FeatureWeight(feature='tx@', weight=4.343753199415493, std=None, value=None), FeatureWeight(feature='db', weight=4.213927539672185, std=None, value=None), FeatureWeight(feature='zd', weight=4.07934438554257, std=None, value=None), FeatureWeight(feature='kf', weight=3.9503038996551103, std=None, value=None), FeatureWeight(feature='sEx', weight=3.8927802493518446, std=None, value=None), FeatureWeight(feature='tn', weight=3.8505896864548457, std=None, value=None), FeatureWeight(feature='tS@', weight=3.8148917890279326, std=None, value=None), FeatureWeight(feature='~', weight=3.7704461463811088, std=None, value=None), FeatureWeight(feature='ys', weight=3.727850363934907, std=None, value=None), FeatureWeight(feature='+@', weight=3.715813301222091, std=None, value=None), FeatureWeight(feature='nej@', weight=3.6868384764868884, std=None, value=None), FeatureWeight(feature='v', weight=3.6817956444617863, std=None, value=None), FeatureWeight(feature='kx', weight=3.60194160112646, std=None, value=None), FeatureWeight(feature='GA', weight=3.5931750006760628, std=None, value=None), FeatureWeight(feature='asi', weight=3.524647026335766, std=None, value=None), FeatureWeight(feature='dAx@', weight=3.5133766019153003, std=None, value=None), FeatureWeight(feature='hut', weight=3.41792297378001, std=None, value=None), FeatureWeight(feature='Ge', weight=3.3696923806087877, std=None, value=None), FeatureWeight(feature='nen', weight=3.358911249446795, std=None, value=None), FeatureWeight(feature='gb', weight=3.3174698504785836, std=None, value=None), FeatureWeight(feature='sx@', weight=3.286448359634688, std=None, value=None), FeatureWeight(feature='@h@', weight=3.2108354553052716, std=None, value=None), FeatureWeight(feature='Gr', weight=3.2004387089552555, std=None, value=None), FeatureWeight(feature='vor', weight=3.1752287346392074, std=None, value=None), FeatureWeight(feature='tm', weight=3.162275461655878, std=None, value=None), FeatureWeight(feature='nm', weight=3.120940122738357, std=None, value=None), FeatureWeight(feature='han', weight=3.1127830330380926, std=None, value=None), FeatureWeight(feature='Ale', weight=3.110217353663704, std=None, value=None), FeatureWeight(feature='rk', weight=3.097 ...

# %%
# top features
feature_names = model.steps[0][1].get_feature_names()
eli5.explain_weights(model.steps[1][1], top=110, feature_names=feature_names, target_names=['VL', 'NL'], targets=['VL', 'NL'])
# Out:
# Explanation(estimator="SGDClassifier(alpha=1e-05, average=False, class_weight='balanced',\n       early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,\n       l1_ratio=0.2, learning_rate='optimal', loss='hinge', max_iter=None,\n       n_iter=None, n_iter_no_change=5, n_jobs=None, penalty='elasticnet',\n       power_t=0.5, random_state=None, shuffle=True, tol=None,\n       validation_fraction=0.1, verbose=0, warm_start=False)", description="\nFeatures with largest coefficients.\nCaveats:\n1. Be careful with features which are not\n   independent - weights don't show their importance.\n2. If scale of input features is different then scale of coefficients\n   will also be different, making direct comparison between coefficient values\n   incorrect.\n3. Depending on regularization, rare features sometimes may have high\n   coefficients; this doesn't mean they contribute much to the\n   classification result for most examples.\n", error=None, method='linear model', is_regression=False, targets=[TargetExplanation(target='VL', feature_weights=FeatureWeights(pos=[FeatureWeight(feature='h@t', weight=5.912547944855458, std=None, value=None), FeatureWeight(feature='G', weight=5.663310678898848, std=None, value=None), FeatureWeight(feature='dA', weight=5.3560807552589464, std=None, value=None), FeatureWeight(feature='@n', weight=5.27880707973565, std=None, value=None), FeatureWeight(feature='v@r', weight=5.164270188857715, std=None, value=None), FeatureWeight(feature='gd', weight=4.997834930976147, std=None, value=None), FeatureWeight(feature='pf', weight=4.711887786979021, std=None, value=None), FeatureWeight(feature='tx', weight=4.5251617831062045, std=None, value=None), FeatureWeight(feature='@r', weight=4.475657079495736, std=None, value=None), FeatureWeight(feature='tx@', weight=4.343753199415493, std=None, value=None), FeatureWeight(feature='db', weight=4.213927539672185, std=None, value=None), FeatureWeight(feature='zd', weight=4.07934438554257, std=None, value=None), FeatureWeight(feature='kf', weight=3.9503038996551103, std=None, value=None), FeatureWeight(feature='sEx', weight=3.8927802493518446, std=None, value=None), FeatureWeight(feature='tn', weight=3.8505896864548457, std=None, value=None), FeatureWeight(feature='tS@', weight=3.8148917890279326, std=None, value=None), FeatureWeight(feature='~', weight=3.7704461463811088, std=None, value=None), FeatureWeight(feature='ys', weight=3.727850363934907, std=None, value=None), FeatureWeight(feature='+@', weight=3.715813301222091, std=None, value=None), FeatureWeight(feature='nej@', weight=3.6868384764868884, std=None, value=None), FeatureWeight(feature='v', weight=3.6817956444617863, std=None, value=None), FeatureWeight(feature='kx', weight=3.60194160112646, std=None, value=None), FeatureWeight(feature='GA', weight=3.5931750006760628, std=None, value=None), FeatureWeight(feature='asi', weight=3.524647026335766, std=None, value=None), FeatureWeight(feature='dAx@', weight=3.5133766019153003, std=None, value=None), FeatureWeight(feature='hut', weight=3.41792297378001, std=None, value=None), FeatureWeight(feature='Ge', weight=3.3696923806087877, std=None, value=None), FeatureWeight(feature='nen', weight=3.358911249446795, std=None, value=None), FeatureWeight(feature='gb', weight=3.3174698504785836, std=None, value=None), FeatureWeight(feature='sx@', weight=3.286448359634688, std=None, value=None), FeatureWeight(feature='@h@', weight=3.2108354553052716, std=None, value=None), FeatureWeight(feature='Gr', weight=3.2004387089552555, std=None, value=None), FeatureWeight(feature='vor', weight=3.1752287346392074, std=None, value=None), FeatureWeight(feature='tm', weight=3.162275461655878, std=None, value=None), FeatureWeight(feature='nm', weight=3.120940122738357, std=None, value=None), FeatureWeight(feature='han', weight=3.1127830330380926, std=None, value=None), FeatureWeight(feature='Ale', weight=3.110217353663704, std=None, value=None), FeatureWeight(feature='rk', weight=3.097 ...
